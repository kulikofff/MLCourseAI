# %%
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"
df = pd.read_csv(DATA_URL + "telecom_churn.csv")
df.head()
df[90:95]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 90    DC              82        510                 No              No
# 91    LA             155        415                 No              No
# 92    AR              80        415                 No              No
# 93    ME              78        415                 No              No
# 94    AZ              90        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 90                      0              143.9               61
# 91                      0              203.4              100
# 92                      0              124.3              100
# 93                      0              252.9               93
# 94                      0              179.1               71
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 90             24.46              194.9              105             16.57
# ...

# %%
print(df.shape)
# Out:
# (3333, 20)

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df["Churn"] = df["Churn"].astype("int64")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df.describe(include=["int64"])
# Out:
#        Account length  Area code  Number vmail messages  Total day calls  \
# count         3333.00    3333.00                3333.00          3333.00
# mean           101.06     437.18                   8.10           100.44
# std             39.82      42.37                  13.69            20.07
# min              1.00     408.00                   0.00             0.00
# 25%             74.00     408.00                   0.00            87.00
# 50%            101.00     415.00                   0.00           101.00
# 75%            127.00     510.00                  20.00           114.00
# max            243.00     510.00                  51.00           165.00
#
#        Total eve calls  Total night calls  Total intl calls  \
# count          3333.00            3333.00           3333.00
# mean            100.11             100.11              4.48
# std              19.92              19.57              2.46
# min               0.00              33.00              0.00
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df["Churn"].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# 0    0.86
# 1    0.14
# Name: Churn, dtype: float64

# %%
df["State"].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OR     78
# OH     78
# WY     77
# VA     77
# CT     74
# MI     73
# VT     73
# ID     73
# UT     72
# TX     72
# IN     71
# KS     70
# MD     70
# NJ     68
# NC     68
# MT     68
# WA     66
# NV     66
# CO     66
# MS     65
# RI     65
# MA     65
# AZ     64
# FL     63
# MO     63
# ND     62
# ME     62
# NM     62
# NE     61
# OK     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
df.sort_values(by=["Churn"],ascending=[True])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 2117    WY             111        415                 No              No
# 2120    UT              81        510                 No              No
# 2121    WA              46        510                 No              No
# 2122    MS              69        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 1263    MA              40        408                 No             Yes
# 2119    CA             111        408                 No              No
# 340     GA              89        415                 No              No
# 2115    CA             138        510                Yes              No
# 1204    IL              78        415                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.sort_values(by=["Total day charge", "Churn"],ascending=[True, False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0                0
# 1397                      0                0.0                0
# 2736                     27                2.6              113
# 2753                      0                7.8               86
# 1986                      0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df["Churn"].mean()
# Out:
# 0.14491449144914492

# %%
df[df["Churn"] == 0].mean()
# Out:
# Account length            100.79
# Area code                 437.07
# Number vmail messages       8.60
# Total day minutes         175.18
# Total day calls           100.28
# Total day charge           29.78
# Total eve minutes         199.04
# Total eve calls           100.04
# Total eve charge           16.92
# Total night minutes       200.13
# Total night calls         100.06
# Total night charge          9.01
# Total intl minutes         10.16
# Total intl calls            4.53
# Total intl charge           2.74
# Customer service calls      1.45
# Churn                       0.00
# dtype: float64

# %%
df[df["Churn"] == 1].mean()
# Out:
# Account length            102.66
# Area code                 437.82
# Number vmail messages       5.12
# Total day minutes         206.91
# Total day calls           101.34
# Total day charge           35.18
# Total eve minutes         212.41
# Total eve calls           100.56
# Total eve charge           18.05
# Total night minutes       205.23
# Total night calls         100.40
# Total night charge          9.24
# Total intl minutes         10.70
# Total intl calls            4.16
# Total intl charge           2.89
# Customer service calls      2.23
# Churn                       1.00
# dtype: float64

# %%
df[df["Churn"] == 1]["Total intl calls"].mean()
# Out:
# 4.163561076604555

# %%
df[(df["Churn"] == 0) & (df["International plan"] == "No")]["Total intl minutes"].max()
# Out:
# 18.9

# %%
df[(df["Churn"] == 0) & (df["International plan"] == "No")]["Total intl minutes"].min()
# Out:
# 0.0

# %%
df[(df["Churn"] == 0) & (df["International plan"] == "No")]["Total intl minutes"].mean()
# Out:
# 10.185472972972972

# %%
df.loc[0:5, "State": "International plan"]
# Out:
#   State  Account length  Area code International plan
# 0    KS             128        415                 No
# 1    OH             107        415                 No
# 2    NJ             137        415                 No
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes

# %%
df.iloc[0:5, 0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
#The first or the last line
#df[1:2]
df[-1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3332             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3332                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3332                       0      0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7408/3087252137.py in <module>
# ----> 1 test #
#
# NameError: name 'test' is not defined
